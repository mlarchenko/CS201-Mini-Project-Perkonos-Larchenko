# %%
# %display latex

# %% [markdown]
# # Симуляція руху подвійного маятника

# %% [markdown]
# Олександра Перконос, Ларченко Максим

# %% [markdown]
# Маємо два фізичні маятники однакової маси та довжини у яких маса розподілена рівномірно по об'єму.
# Один маятник кріпиться до кінця другого. Їх рух обмежений двовимірною площиною.

# %% [markdown]
# <img src="pendulum.png" width="300">

# %% [markdown]
# Введемо наступні позначення як показано на малюнку:
# ($x_1$, $y_1$), ($x_2$, $y_2$) - координати **центрів мас** першого та другого маятника відповідно
# $\theta_1, \theta_2$ - кути відхиленння від вертикалі маятників
# l, m, g - відповідно довжина, маса кожного з маятників та прискорення вільного падіння.
# Початок координат декартової системи розташувається в точці кріплення верхнього маятника.

# %% [markdown]
# Знайдемо зв'язок між координатами ($x_1$, $y_1$), ($x_2$, $y_2$) та кутами $\theta_1, \theta_2$.
# Маємо:
# $$x_1 = \frac{1}{2} \ell \sin \theta_1$$
# $$y_1 = -\frac{1}{2} \ell \cos \theta_1$$
# $$x_2 = \ell \left( \sin \theta_1 + \frac{1}{2} \sin \theta_2 \right)$$
# $$y_2 = -\ell \left( \cos \theta_1 + \frac{1}{2} \cos \theta_2 \right)$$

# %% [markdown]
# Виведемо рівняння руху, що повертатиме кути $\theta_1, \theta_2$, швидкості руху центрів мас та їх прискорення в заданий момент часу $t$. Для цього використаємо Лагранжіан
# $$ \mathcal{L}  = W_k - W_p$$
# де $W_k$, $W_p$ - кінетична та потенціальна енергії механічної системи.
# Лагранжіан дозволяє визначити стан системи в довільний момент часу через взаємозв'язок кінетичної енергії (швидкість) та потенціальної енергії (висота).
#
# Кінетична енергія тіла є сумою кінетичної енергії його поступального руху $\frac{mv^2}{2}$ та обертального $\frac{I \omega^2}{2}$, де $I$ - момент інерції, а $\omega$ - кутова швидкість. В нашому випадку момент інерції обчислюється як $$I = \frac{m \ell^2}{12}$$ Потенціальна енергія - це $mgh$, отже маємо для нашого випадку
# $$
# L= \frac{1}{2} m \left( v_1^2 + v_2^2 \right) + \frac{1}{2} I \left( \omega_1^2 + \omega_2^2 \right) - mg(y_1 + y_2)
# $$
# Позначатимо похідну функції по часу через точку згори. Матимемо
# $$\omega_i = \dot{\theta_i}$$
# Також за теоремою Піфагора знайдемо швидкості
# $$v^2 = v_x^2 + v_y^2$$
# де
# $$v_x = \dot{x}, v_y = \dot{y}$$

# %%
import numpy as np
from sage.calculus.desolvers import desolve_odeint
from scipy.integrate import odeint

# %%
# %display latex

# %%
var('l g')

# %%
var('theta1 theta2 dtheta1 dtheta2')

# %%
var('ddtheta1 ddtheta2')

# %%
eq1 = (
    (4/3)*l*ddtheta1 
    + (1/2)*l*ddtheta2*cos(theta1 - theta2) 
    + (1/2)*l*(dtheta2^2)*sin(theta1 - theta2) 
    + (3/2)*g*sin(theta1) == 0
)

# %%
eq2 = (
    (1/3)*l*ddtheta2 
    + (1/2)*l*ddtheta1*cos(theta1 - theta2) 
    - (1/2)*l*(dtheta1^2)*sin(theta1 - theta2)
    + (1/2)*g*sin(theta2) == 0
)

# %%
solutions = solve([eq1, eq2], ddtheta1, ddtheta2)

# %%
print(solutions[0][0])

# %%
print(solutions[0][1])

# %% [markdown]
# ми отримали рівняння що виражають прискорення першого та другого маятників відносно їх кутів та кутових швидкостей

# %% [markdown]
# Ми розглядаємо систему, що складається з двох послідовно з'єднаних маятників
#
# **Параметри системи:**
# * $l_1, l_2$ — довжини першого та другого стрижнів (у нашому випадку $l_1 = l_2$).
# * $m_1, m_2$ — маси тягарців на кінцях стрижнів.
# * $\theta_1, \theta_2$ — кути відхилення від вертикалі (у радіанах).
# * $g$ — прискорення вільного падіння ($9.81 \, м/с^2$).
#
# Стан системи в будь-який момент часу $t$ описується вектором:
# $$y(t) = [\theta_1(t), \omega_1(t), \theta_2(t), \omega_2(t)]$$
# де $\omega = \dot{\theta}$ — кутова швидкість.

# %% [markdown]
# hkyucsdcsd

# %%
g = 9.81
m = 1.0
l = 1.0

def double_pendulum(y, t):
    theta1, dtheta1, theta2, dtheta2 = y[0], y[1], y[2], y[3]
    delta = theta1 - theta2
    dy1_dt = dtheta1
    dy3_dt = dtheta2

    dy2_dt = -3*(3*g*cos(-theta1 + theta2)*sin(theta2) - 6*g*sin(theta1) + (3*dtheta1^2*l*cos(-theta1 + theta2) + 2*dtheta2^2*l)*sin(-theta1 + theta2))/(9*l*cos(-theta1 + theta2)^2 - 16*l)
    dy4_dt = -3*(9*g*cos(-theta1 + theta2)*sin(theta1) - (3*dtheta2^2*l*cos(-theta1 + theta2) + 8*dtheta1^2*l)*sin(-theta1 + theta2) - 8*g*sin(theta2))/(9*l*cos(-theta1 + theta2)^2 - 16*l)

    return [dy1_dt, dy2_dt, dy3_dt, dy4_dt]

start_cond = [float(pi/2), 0.0, float(pi/2), 0.0]

time_period = np.linspace(0, 10, 1000)

solution = odeint(double_pendulum, start_cond, time_period)

theta1 = solution[:, 0]
theta2 = solution[:, 2]

x1 = l * np.sin(theta1)
y1 = -l * np.cos(theta1)

x2 = x1 + l * np.sin(theta2)
y2 = y1 - l * np.cos(theta2)

p = list_plot(list(zip(x2, y2)), plotjoined=True, color='red', axes_labels=['X', 'Y'], title="Траєкторія подвійного маятника")
show(p)
